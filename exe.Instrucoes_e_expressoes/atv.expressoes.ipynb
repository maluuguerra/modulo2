# %%
print("Q1")
salario = 20
horas = 40

Sbruto = salario * horas
DescontoINSS =  (Sbruto * 0.1)
DescontoSindicato =  (Sbruto * 0.05)
Liquido = Sbruto - DescontoINSS - DescontoSindicato

print("Salario Bruto:",Sbruto)
print("Desconto INSS: ",DescontoINSS)
print("Desconto Sindicato:",DescontoSindicato)
print("Salario Liquido:",Liquido)
# Out:
# Q1
# Salario Bruto: 800
# Desconto INSS:  80.0
# Desconto Sindicato: 40.0
# Salario Liquido: 680.0

# %%
print("Q2")
salario = 20
horas = 40

Sbruto = salario * horas
liquido = Sbruto - (Sbruto * 0.1) - (Sbruto * 0.05)
print("Salario Bruto :", Sbruto)
print("Salario liquido: ", liquido)
# Out:
# Q2
# Salario Bruto : 800
# Salario liquido:  680.0

# %%
print("Q3")

cambioReal = 0.69
reais = 100
yuan = reais * cambioReal

print("Valor em yuan:", yuan)
# Out:
# Q3
# Valor em yuan: 69.0

# %%
print("Q4")

dist = 42.195
tempo = 3
v_media = dist / tempo

print("Velociade media: ", v_media)
# Out:
# Q4
# Velociade media:  14.065
